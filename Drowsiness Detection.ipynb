# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (0.19.1)
# Requirement already satisfied: torchaudio in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from sympy->torch) (1.3.0)

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !pip install -r requirements.txt
# install
# Out:
# Requirement already satisfied: torch>=1.7.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: torchvision>=0.8.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (0.19.1)
# Requirement already satisfied: torchaudio>=0.7.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (2.4.1)
# Collecting matplotlib>=3.3.0 (from -r requirements.txt (line 4))
#   Downloading matplotlib-3.7.5-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.7 kB)
# Collecting opencv-python-headless>=4.5.1.48 (from -r requirements.txt (line 5))
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (1.24.4)
# Collecting pandas>=1.1.5 (from -r requirements.txt (line 7))
#   Downloading pandas-2.0.3-cp38-cp38-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting PyYAML>=5.3.1 (from -r requirements.txt (line 8))
#   Downloading pyyaml-6.0.2.tar.gz (130 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tqdm>=4.41.0 (from -r requirements.txt (line 9))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting seaborn>=0.11.0 (from -r requirements.txt (line 10))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting streamlit>=1.5.0 (from -r requirements.txt (line 11))
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting pyqt5>=5.15.4 (from -r requirements.txt (line 12))
#   Using cached PyQt5-5.15.11-cp38-abi3-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting lxml>=4.6.2 (from -r requirements.txt (line 13))
#   Downloading lxml-5.3.0.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 12.3 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 1)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 1)) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 1)) (3.1.5)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 1)) (2024.12.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torchvision>=0.8.0->-r requirements.txt (line 2)) (10.4.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->-r requirements.txt (line 4))
#   Downloading contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->-r requirements.txt (line 4))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->-r requirements.txt (line 4))
#   Downloading fonttools-4.55.3-cp38-cp38-macosx_10_9_universal2.whl.metadata (165 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib>=3.3.0->-r requirements.txt (line 4))
#   Downloading kiwisolver-1.4.7-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib>=3.3.0->-r requirements.txt (line 4)) (24.2)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3.0->-r requirements.txt (line 4))
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib>=3.3.0->-r requirements.txt (line 4)) (2.9.0)
# Collecting importlib-resources>=3.2.0 (from matplotlib>=3.3.0->-r requirements.txt (line 4))
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting pytz>=2020.1 (from pandas>=1.1.5->-r requirements.txt (line 7))
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas>=1.1.5->-r requirements.txt (line 7))
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting altair<6,>=4.0 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting click<9,>=7.0 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf<6,>=3.20 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Downloading pyarrow-17.0.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting requests<3,>=2.27 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich<14,>=10.14.0 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.5.0->-r requirements.txt (line 11)) (6.4.1)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5>=5.15.4->-r requirements.txt (line 12))
#   Downloading PyQt5_sip-12.15.0-cp38-cp38-macosx_11_0_universal2.whl.metadata (421 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5>=5.15.4->-r requirements.txt (line 12))
#   Using cached PyQt5_Qt5-5.15.16-py3-none-macosx_11_0_arm64.whl.metadata (536 bytes)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached narwhals-1.22.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->-r requirements.txt (line 4)) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from jinja2->torch>=1.7.0->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->-r requirements.txt (line 4)) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.27->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Downloading charset_normalizer-3.4.1-cp38-cp38-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.27->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.27->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.27->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit>=1.5.0->-r requirements.txt (line 11)) (2.18.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from sympy->torch>=1.7.0->-r requirements.txt (line 1)) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Downloading rpds_py-0.20.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.5.0->-r requirements.txt (line 11))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading matplotlib-3.7.5-cp38-cp38-macosx_11_0_arm64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 11.9 MB/s eta 0:00:00a 0:00:01
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
# Downloading pandas-2.0.3-cp38-cp38-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 15.1 MB/s eta 0:00:00 0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 15.7 MB/s eta 0:00:00a 0:00:01
# Using cached PyQt5-5.15.11-cp38-abi3-macosx_11_0_arm64.whl (6.6 MB)
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 24.3 MB/s eta 0:00:00
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp38-cp38-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 16.3 MB/s eta 0:00:00
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading kiwisolver-1.4.7-cp38-cp38-macosx_11_0_arm64.whl (64 kB)
# Using cached protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Downloading pyarrow-17.0.0-cp38-cp38-macosx_11_0_arm64.whl (27.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 13.9 MB/s eta 0:00:00a 0:00:01
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Using cached PyQt5_Qt5-5.15.16-py3-none-macosx_11_0_arm64.whl (37.1 MB)
# Downloading PyQt5_sip-12.15.0-cp38-cp38-macosx_11_0_universal2.whl (122 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached certifi-2024.12.14-py3-none-any.whl (164 kB)
# Downloading charset_normalizer-3.4.1-cp38-cp38-macosx_10_9_universal2.whl (195 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached narwhals-1.22.0-py3-none-any.whl (297 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached attrs-24.3.0-py3-none-any.whl (63 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.20.1-cp38-cp38-macosx_11_0_arm64.whl (318 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Building wheels for collected packages: PyYAML, lxml
#   Building wheel for PyYAML (pyproject.toml) ... done
#   Created wheel for PyYAML: filename=PyYAML-6.0.2-cp38-cp38-macosx_11_0_arm64.whl size=45366 sha256=63ce4863986f66ab84974a90523974b3419ad017896645b073f29e28e05ea984
#   Stored in directory: /Users/shubhamdarkad/Library/Caches/pip/wheels/ab/34/2b/5ad179dc5914ad34b84b05b4fd1c3f7a39fee3e771ddf534a4
#   Building wheel for lxml (pyproject.toml) ... done
#   Created wheel for lxml: filename=lxml-5.3.0-cp38-cp38-macosx_11_0_arm64.whl size=1484400 sha256=c00c08a8b1fac478c91868eb1e685391fd2f930d0c8dc21db39366a689d82d5e
#   Stored in directory: /Users/shubhamdarkad/Library/Caches/pip/wheels/37/19/50/80ff9642d74365e416a0b370a5784afd3167f4e1182644c30b
# Successfully built PyYAML lxml
# Installing collected packages: pytz, PyQt5-Qt5, urllib3, tzdata, tqdm, toml, tenacity, smmap, rpds-py, PyYAML, PyQt5-sip, pyparsing, pyarrow, protobuf, pkgutil-resolve-name, opencv-python-headless, narwhals, mdurl, lxml, kiwisolver, importlib-resources, idna, fonttools, cycler, contourpy, click, charset-normalizer, certifi, cachetools, blinker, attrs, requests, referencing, pyqt5, pydeck, pandas, matplotlib, markdown-it-py, gitdb, seaborn, rich, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed PyQt5-Qt5-5.15.16 PyQt5-sip-12.15.0 PyYAML-6.0.2 altair-5.4.1 attrs-24.3.0 blinker-1.8.2 cachetools-5.5.0 certifi-2024.12.14 charset-normalizer-3.4.1 click-8.1.8 contourpy-1.1.1 cycler-0.12.1 fonttools-4.55.3 gitdb-4.0.12 gitpython-3.1.44 idna-3.10 importlib-resources-6.4.5 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 kiwisolver-1.4.7 lxml-5.3.0 markdown-it-py-3.0.0 matplotlib-3.7.5 mdurl-0.1.2 narwhals-1.22.0 opencv-python-headless-4.10.0.84 pandas-2.0.3 pkgutil-resolve-name-1.3.10 protobuf-5.29.3 pyarrow-17.0.0 pydeck-0.9.1 pyparsing-3.1.4 pyqt5-5.15.11 pytz-2024.2 referencing-0.35.1 requests-2.32.3 rich-13.9.4 rpds-py-0.20.1 seaborn-0.13.2 smmap-5.0.2 streamlit-1.40.1 tenacity-9.0.0 toml-0.10.2 tqdm-4.67.1 tzdata-2024.2 urllib3-2.2.3

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-1-14 Python-3.8.20 torch-2.4.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode='nearest')
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode='nearest')
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # 3. Make Detections with Images

# %%
#img = 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg/800px-Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg'

# %%
img1 = 'london.png'

# %%
results = model(img1)
results.print()
# Out:
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 967x1451 11 persons, 3 cars, 1 motorcycle, 1 bus, 2 traffic lights, 1 handbag
# Speed: 155.4ms pre-process, 62.2ms inference, 1.4ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img2 = 'source_1.png'

# %%
results = model(img2)
results.print()
# Out:
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 853x1280 1 person, 7 cars, 1 bus, 2 trucks
# Speed: 44.3ms pre-process, 63.0ms inference, 0.5ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[ 14,  32,  54],
#          [ 40,  61,  82],
#          [ 33,  59,  82],
#          ...,
#          [129, 200, 254],
#          [131, 202, 255],
#          [133, 204, 255]],
#
#         [[ 10,  36,  61],
#          [ 38,  66,  90],
#          [102, 134, 159],
#          ...,
#          [128, 199, 253],
#          [130, 201, 255],
#          [132, 203, 255]],
#
#         [[ 25,  69,  98],
#          [ 39,  83, 112],
#          [ 73, 117, 146],
#          ...,
#          [127, 198, 252],
#          [128, 199, 253],
#          [130, 201, 255]],
#
#         ...,
#
#         [[ 83,  86,  91],
#          [ 83,  86,  91],
#          [ 84,  87,  92],
#          ...,
#          [ 53,  83, 119],
#          [ 55,  85, 123],
#          [ 57,  87, 123]],
#
#         [[107, 111, 114],
#          [110, 114, 115],
#          [115, 119, 122],
#          ...,
#          [ 54,  83, 123],
#          [ 54,  83, 123],
#          [ 56,  85, 125]],
#
#         [[135, 136, 138],
#          [136, 138, 137],
#          [136, 137, 139],
#          ...,
#          [ 57,  86, 128],
#          [ 58,  87, 129],
#          [ 60,  89, 131]]], dtype=uint8)]

# %% [markdown]
# # 4. Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-01-14 16:34:31.622 python[6065:67960] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 2025-01-14 16:34:33.578 python[6065:67960] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-14 16:34:33.578 python[6065:67960] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %% [markdown]
# # 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
import cv2

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for awake
# Collecting images for awake, image number 0
# Collecting images for awake, image number 1
# Collecting images for awake, image number 2
# Collecting images for awake, image number 3
# 2025-01-14 16:38:15.610 python[6817:72971] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-14 16:38:15.610 python[6817:72971] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Collecting images for awake, image number 4
# Collecting images for awake, image number 5
# Collecting images for awake, image number 6
# Collecting images for awake, image number 7
# Collecting images for awake, image number 8
# Collecting images for awake, image number 9
# Collecting images for awake, image number 10
# Collecting images for awake, image number 11
# Collecting images for awake, image number 12
# Collecting images for awake, image number 13
# Collecting images for awake, image number 14
# Collecting images for awake, image number 15
# Collecting images for awake, image number 16
# Collecting images for awake, image number 17
# Collecting images for awake, image number 18
# Collecting images for awake, image number 19
# Collecting images for drowsy
# Collecting images for drowsy, image number 0
# Collecting images for drowsy, image number 1
# Collecting images for drowsy, image number 2
# Collecting images for drowsy, image number 3
# Collecting images for drowsy, image number 4
# Collecting images for drowsy, image number 5
# Collecting images for drowsy, image number 6
# Collecting images for drowsy, image number 7
# Collecting images for drowsy, image number 8
# Collecting images for drowsy, image number 9
# Collecting images for drowsy, image number 10
# Collecting images for drowsy, image number 11
# Collecting images for drowsy, image number 12
# Collecting images for drowsy, image number 13
# Collecting images for drowsy, image number 14
# Collecting images for drowsy, image number 15
# Collecting images for drowsy, image number 16
# Collecting images for drowsy, image number 17
# Collecting images for drowsy, image number 18
# Collecting images for drowsy, image number 19

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data/images/awake.2c870894-d296-11ef-a2a8-620eab49aa93.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# Collecting images for awake
# Collecting images for awake, image number 0
# data/images/awake.2dd07e6a-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 1
# data/images/awake.2dd07f5a-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 2
# data/images/awake.2dd07faa-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 3
# data/images/awake.2dd07ff0-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 4
# data/images/awake.2dd0802c-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 5
# data/images/awake.2dd08068-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 6
# data/images/awake.2dd080a4-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 7
# data/images/awake.2dd080e0-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 8
# data/images/awake.2dd0811c-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 9
# data/images/awake.2dd08158-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 10
# data/images/awake.2dd08194-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 11
# data/images/awake.2dd081d0-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 12
# data/images/awake.2dd08202-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 13
# data/images/awake.2dd0823e-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 14
# data/images/awake.2dd0827a-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 15
# data/images/awake.2dd082b6-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 16
# data/images/awake.2dd082e8-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 17
# data/images/awake.2dd08324-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 18
# data/images/awake.2dd08360-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for awake, image number 19
# data/images/awake.2dd0839c-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy
# Collecting images for drowsy, image number 0
# data/images/drowsy.2dd083f6-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 1
# data/images/drowsy.2dd08432-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 2
# data/images/drowsy.2dd0846e-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 3
# data/images/drowsy.2dd084a0-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 4
# data/images/drowsy.2dd084dc-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 5
# data/images/drowsy.2dd0850e-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 6
# data/images/drowsy.2dd08554-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 7
# data/images/drowsy.2dd08590-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 8
# data/images/drowsy.2dd085c2-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 9
# data/images/drowsy.2dd085fe-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 10
# data/images/drowsy.2dd0863a-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 11
# data/images/drowsy.2dd08676-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 12
# data/images/drowsy.2dd086a8-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 13
# data/images/drowsy.2dd086e4-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 14
# data/images/drowsy.2dd08716-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 15
# data/images/drowsy.2dd08752-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 16
# data/images/drowsy.2dd0878e-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 17
# data/images/drowsy.2dd087c0-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 18
# data/images/drowsy.2dd087fc-d296-11ef-a2a8-620eab49aa93.jpg
# Collecting images for drowsy, image number 19
# data/images/drowsy.2dd08838-d296-11ef-a2a8-620eab49aa93.jpg

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !brew install qt  # Install qt-5.x.x by Homebrew
# !brew install libxml2
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# acronym                    humanlog                   render
# aliae                      idsgrep                    replxx
# atac                       imgp                       repren
# aws-c-auth                 ipatool                    reveal-md
# aws-c-cal                  jwt-cli                    rogcat
# aws-c-common               kool                       rshijack
# aws-c-compression          kraftkit                   ruby@3.3
# aws-c-event-stream         kube-bench                 runitor
# aws-c-http                 kubernetes-cli@1.31        s5cmd
# aws-c-io                   kubetrim                   scooter
# aws-c-mqtt                 languagetool-rust          sendme
# aws-c-s3                   leetcode-cli               sentry-cli
# aws-c-sdkutils             legba                      sequin
# aws-checksums              libesedb                   serie
# aws-crt-cpp                libformfactor              sesh
# azure-core-cpp             libgit2@1.8                sfml@2
# azurehound                 libheinz                   sfsexp
# bender                     libkeyfinder               showcert
# bruno-cli                  librime                    slepc
# cargo-chef                 libsidplayfp               slepc-complex
# cargo-dist                 libsvgtiny                 slumber
# cargo-flamegraph           libunicode                 spytrap-adb
# cargo-msrv                 limbo                      sqlitecpp
# cargo-public-api           lla                        sshx
# cargo-run-bin              lol-html                   starlark-rust
# cargo-shuttle              ltex-ls-plus               static-web-server
# cdncheck                   macmon                     streamrip
# chaos-client               mago                       swc
# cloudquery                 malcontent                 swctl
# cobo-cli                   marisa                     synchrony
# cobra-cli                  mdz                        tabulate
# codeberg-cli               meli                       tach
# codesnap                   minio-warp                 talosctl
# codevis                    mmdbctl                    television
# cpp-peglib                 monocle                    templ
# crates-tui                 netatalk                   tenere
# directx-headers            neverest                   termbg
# draft                      nrm                        the-way
# dragonbox                  odbc2parquet               tiny
# dry                        openapi-tui                tomcat@10
# ducker                     oranda                     topiary
# dum                        parallel-disk-usage        tuisky
# eventpp                    parca                      typeshare
# fairy-stockfish            parlay                     tzdb
# funzzy                     periphery                  vals
# fzf-make                   pie                        versitygw
# gh-ost                     pinact                     vgt
# ghc@9.10                   pipelight                  victorialogs
# git-ignore                 pistache                   vo-amrwbenc
# glaze                      pixi-pack                  vue-language-server
# glibc@2.17                 planus                     wails
# go-blueprint               poselib                    watcher
# go-parquet-tools           posting                    wcstools
# gopeed                     protoc-gen-grpc-java       weaviate
# graphql-inspector          proxyfor                   weaviate-cli
# gsan                       pscale                     wgo
# gurk                       qbec                       xc
# harlequin                  rapidyaml                  xmq
# harper                     ratify                     yozefu
# heroku                     redka                      zsh-f-sy-h
# hgrep                      regal
# ==> New Casks
# alcove                                   font-playwrite-it-trad-guides
# aw-edid-editor                           font-playwrite-mx-guides
# ayugram                                  font-playwrite-ng-modern-guides
# bananas                                  font-playwrite-nl-guides
# beaver-notes                             font-playwrite-no-guides
# bindiff                                  font-playwrite-nz-guides
# bookmacster@beta                         font-playwrite-pe-guides
# clipbook                                 font-playwrite-pl-guides
# dehesselle-meld                          font-playwrite-pt-guides
# dorico                                   font-playwrite-ro-guides
# fastdmg                                  font-playwrite-sk-guides
# font-agu-display                         font-playwrite-tz-guides
# font-atkinson-hyperlegible-mono          font-playwrite-us-modern-guides
# font-atkinson-hyperlegible-next          font-playwrite-us-trad-guides
# font-badeen-display                      font-playwrite-vn-guides
# font-brass-mono                          font-playwrite-za-guides
# font-bravura                             font-pochaevsk
# font-cica-without-emoji                  font-ponomar
# font-fairfax-hd                          font-shafarik
# font-gd-highwaygothicja                  font-sketchybar-app-font
# font-ibm-plex-sans-sc                    font-tagesschrift
# font-kanchenjunga                        font-tamzen
# font-kreative-square                     font-triodion
# font-moralerspace                        font-udev-gothic-hs
# font-moralerspace-hw                     fontcreator
# font-moralerspace-hw-jpdoc               ghostty
# font-moralerspace-hw-nf                  ghostty@tip
# font-moralerspace-jpdoc                  green-go-control
# font-moralerspace-nf                     halion-sonic
# font-nanum-square                        helio
# font-nanum-square-neo                    ishare
# font-nanum-square-round                  istherenet
# font-playwrite-ar-guides                 macai
# font-playwrite-at-guides                 meridiem
# font-playwrite-au-nsw-guides             mihomo-party
# font-playwrite-au-qld-guides             mindmaster-cn
# font-playwrite-au-sa-guides              mixing-station
# font-playwrite-au-tas-guides             mouseless
# font-playwrite-au-vic-guides             nexonplug
# font-playwrite-be-vlg-guides             nvidia-nsight-systems
# font-playwrite-be-wal-guides             octarine
# font-playwrite-br-guides                 openhv
# font-playwrite-ca-guides                 radiola
# font-playwrite-cl-guides                 readest
# font-playwrite-co-guides                 restic-browser
# font-playwrite-cu-guides                 rivet
# font-playwrite-cz-guides                 rode-virtual-channels
# font-playwrite-de-grund-guides           satdump
# font-playwrite-de-la-guides              satyrn
# font-playwrite-de-sas-guides             serial-studio
# font-playwrite-de-va-guides              soundsource@test
# font-playwrite-dk-loopet-guides          steinberg-download-assistant
# font-playwrite-dk-uloopet-guides         steinberg-library-manager
# font-playwrite-es-deco-guides            steinberg-mediabay
# font-playwrite-es-guides                 stratoshark
# font-playwrite-fr-moderne-guides         superwhisper
# font-playwrite-fr-trad-guides            supremo
# font-playwrite-gb-j-guides               sys-pc-tool
# font-playwrite-gb-s-guides               tabtab
# font-playwrite-hr-guides                 tm-error-logger
# font-playwrite-hr-lijeva-guides          tpvirtual
# font-playwrite-hu-guides                 website-audit
# font-playwrite-id-guides                 widgettoggler
# font-playwrite-ie-guides                 windsurf
# font-playwrite-in-guides                 wizcli
# font-playwrite-is-guides                 zen-browser@twilight
# font-playwrite-it-moderna-guides
#
# You have 15 outdated formulae installed.
#
# Warning: qt 6.7.3 is already installed and up-to-date.
# To reinstall 6.7.3, run:
#   brew reinstall qt
# Warning: libxml2 2.13.5 is already installed and up-to-date.
# To reinstall 2.13.5, run:
#   brew reinstall libxml2

# %%
# !pip3 install pyqt5 lxml # Install qt and lxml by pip
# Out:
# Requirement already satisfied: pyqt5 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (5.15.11)
# Requirement already satisfied: lxml in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (5.3.0)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from pyqt5) (12.15.0)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from pyqt5) (5.15.16)

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 39 (delta 6), reused 2 (delta 2), pack-reused 24 (from 1)
# Unpacking objects: 100% (39/39), 158.28 KiB | 4.28 MiB/s, done.
# From https://github.com/ultralytics/yolov5
#    6981c274..6420a1db  master     -> origin/master
# github: ⚠️ YOLOv5 is out of date by 10 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# requirements: Ultralytics requirement ['thop>=0.1.1'] not found, attempting AutoUpdate...
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from thop>=0.1.1) (2.4.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch->thop>=0.1.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch->thop>=0.1.1) (4.12.2)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch->thop>=0.1.1) (1.13.3)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch->thop>=0.1.1) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch->thop>=0.1.1) (3.1.5)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from torch->thop>=0.1.1) (2024.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from jinja2->torch->thop>=0.1.1) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/myenv/lib/python3.8/site-packages (from sympy->torch->thop>=0.1.1) (1.3.0)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['thop>=0.1.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-385-gb968b2d7 Python-3.8.20 torch-2.4.1 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=17
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     59334  models.yolo.Detect                      [17, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7065478 parameters, 7065478 gradients, 16.1 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /Users/shubhamdarkad/Desktop/DriverDrowsy/App/data/labels... 40
# train: New cache created: /Users/shubhamdarkad/Desktop/DriverDrowsy/App/data/labels.cache
# val: Scanning /Users/shubhamdarkad/Desktop/DriverDrowsy/App/data/labels.cache...
#
# AutoAnchor: 5.55 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp6/labels.jpg...
# train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs/train/exp6
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/6 [00:00<?, ?it/s]train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       0/499         0G     0.1162    0.01012    0.07911         19        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       0/499         0G      0.114    0.01018    0.07735         16        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       0/499         0G     0.1137   0.009476    0.07656         11        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       0/499         0G     0.1149   0.009188    0.07574         14        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       0/499         0G     0.1155   0.009066    0.07562         13        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       0/499         0G     0.1127   0.008947    0.07571          7        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         90         40     0.0017      0.167     0.0291    0.00584
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/6 [00:00<?, ?it/s]train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       1/499         0G     0.1087    0.01177    0.07229         19        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       1/499         0G     0.1064    0.01012    0.07207         11        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       1/499         0G     0.1056   0.009994    0.07372         14        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       1/499         0G     0.1045    0.01007    0.07281         13        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       1/499         0G     0.1026    0.01111    0.07243         24        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       1/499         0G     0.1023    0.01166     0.0716         14        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         90         40    0.00226      0.235    0.00665    0.00133
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/6 [00:00<?, ?it/s]train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       2/499         0G    0.09036    0.01221    0.06578         16        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       2/499         0G    0.08503    0.01526    0.06591         21        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       2/499         0G    0.08494    0.01368    0.06569         13        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       2/499         0G     0.0869    0.01233    0.06617         10        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       2/499         0G    0.08393    0.01268    0.06494         15        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       2/499         0G    0.08172    0.01332    0.06366         10        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         90         40    0.00535       0.52     0.0416     0.0094
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/6 [00:00<?, ?it/s]train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       3/499         0G      0.074    0.01721    0.05716         19        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       3/499         0G    0.07409    0.01739    0.05782         18        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       3/499         0G    0.07549    0.01774    0.05814         25        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       3/499         0G    0.07508    0.01741    0.05699         20        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       3/499         0G    0.07589    0.01634    0.05766         15        320:  train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       3/499         0G    0.07491    0.01578    0.05789          8        320: 1
#                  Class     Images  Instances          P          R      mAP50   ^C
#                  Class     Images  Instances          P          R      mAP50
# Traceback (most recent call last):
#   File "train.py", line 986, in <module>
#     main(opt)
#   File "train.py", line 688, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "train.py", line 457, in train
#     results, maps, _ = validate.run(
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/Users/shubhamdarkad/Desktop/DriverDrowsy/App/yolov5/val.py", line 341, in run
#     preds, train_out = model(im) if compute_loss else (model(im, augment=augment), None)
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/shubhamdarkad/Desktop/DriverDrowsy/App/yolov5/models/yolo.py", line 270, in forward
#     return self._forward_once(x, profile, visualize)  # single-scale inference, train
#   File "/Users/shubhamdarkad/Desktop/DriverDrowsy/App/yolov5/models/yolo.py", line 169, in _forward_once
#     x = m(x)  # run
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/shubhamdarkad/Desktop/DriverDrowsy/App/yolov5/models/common.py", line 340, in forward
#     return self.cv2(torch.cat((x, y1, y2, self.m(y2)), 1))
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/shubhamdarkad/Desktop/DriverDrowsy/App/yolov5/models/common.py", line 87, in forward
#     return self.act(self.bn(self.conv(x)))
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 458, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 454, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
# KeyboardInterrupt

# %% [markdown]
# # 6. Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp4/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /Users/shubhamdarkad/.cache/torch/hub/master.zip
# YOLOv5 🚀 2025-1-14 Python-3.8.20 torch-2.4.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'awake.0a822f6a-a81d-11ef-a811-620eab49aa93.jpg')

# %%
results = model(img)
# Out:
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
results.print()
# Out:
# image 1/1: 1080x1920 1 awake
# Speed: 23.2ms pre-process, 60.9ms inference, 0.6ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/shubhamdarkad/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:895: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
